# %% [markdown]
# # Type Casting

# %% [markdown]
# Converting from one data type to another

# %% [markdown]
# * to be check- mutability immutability
# * fundamental, functional datatypes

# %%
a=10
type(a)
# Out:
# int

# %%
float(a)
# Out:
# 10.0

# %%
bool(a)
# Out:
# True

# %%
str(a)
# Out:
# '10'

# %%
b=13.45
type(b)
# Out:
# float

# %%
int(b)
# Out:
# 13

# %%
str(b)
# Out:
# '13.45'

# %%
bool(b)
# Out:
# True

# %% [markdown]
# String- Cant be converted to anything except bool

# %%
name="M"

# %%
bool(name)
# Out:
# True

# %%
n=""

# %%
bool(n)
# Out:
# False

# %% [markdown]
# complex- can't be converted to int,float/ not possible(np)

# %%
comp=5+8j
type(comp)
# Out:
# complex

# %%
str(comp)
# Out:
# '(5+8j)'

# %%
bool(comp)
# Out:
# True
