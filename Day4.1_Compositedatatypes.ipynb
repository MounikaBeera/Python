# %% [markdown]
# # Composite Data Types

# %% [markdown]
# ### Bytes Data types

# %%
b=[10,20,30,40,50]
type(b)
# Out:
# list

# %% [markdown]
# can't modify the value of bytes array (b)
# it soesnot support item assignment because it is immutable
# once we define we cannot change

# %%
a=bytes(b)
type(a)
# Out:
# bytes

# %% [markdown]
# a[1]=16
# *error -> 'bytes' object does not support item assignment*

# %%
for i in a:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
a[0]
# Out:
# 10

# %% [markdown]
# ### Bytesarray Datatype

# %% [markdown]
# *It is same as bytes datatype because it is mutable*

# %%
y=[10,20,30,40,50]

# %%
ba=bytearray(y)

# %%
for i in ba:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
ba[2]
# Out:
# 30

# %%
ba[2]=43

# %%
for i in ba:
    print(i)
# Out:
# 10
# 20
# 43
# 40
# 50

# %% [markdown]
# ### List

# %% [markdown]
# *If we want to represent a group of data as a single entity where:*
# 1. *Insertion order is preserved*
# 2. *hetrogeneous elements are allowed*
# 3. *Duplicates are allowed*
# 4. *Growable in nature*
# 5. *It's mutable*
# 6. *Value enclosed in [] and seperated by ,*

# %% [raw]
# Collection of hetrogeneous elements(can be int,float,str or anything)

# %%
list1=[10,20.4,"zade",7+8j,True,10]

# %%
list1[0]
# Out:
# 10

# %%
list1[3]
# Out:
# (7+8j)

# %%
list1[5]=35

# %%
list1.append(124)

# %%
list1
# Out:
# [10, 20.4, 'zade', (7+8j), True, 35, 124]

# %%
list1.insert(7,145)

# %%
list1
# Out:
# [10, 20.4, 'zade', (7+8j), True, 35, 124, 145]

# %%
list1.remove(124)

# %%
list1
# Out:
# [10, 20.4, 'zade', (7+8j), True, 35, 145]
